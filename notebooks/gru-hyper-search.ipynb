# %%
import pandas as pd
import numpy as np 
from itertools import product

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential 
from keras.layers import Dense, Dropout, GRU, Input
from keras.utils import pad_sequences
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('../data/asfp_cleaned_features.csv')

# %%
##############################
#### Hyperparameter Grid ####
##############################

feature_cols = ['water_temp', 'ph', 'ec', 'do', 'dt_seconds', 'segment', 'hour', 'dayofweek', 'month', 'water_temp_roll1h_mean', 'ph_roll1h_mean', 'ec_roll1h_mean', 'do_roll1h_mean']
input_features = ['water_temp', 'ph', 'ec', 'do', 'dt_seconds', 'hour', 'dayofweek', 'month']
output_features = ['water_temp', 'ph', 'ec', 'do']
n_inputs = len(input_features)
n_outputs = len(output_features)
pred_horizon = 6

param_grid = {
    'layer_units': [(64, 32), (128, 64)],
    'learning_rate': [0.001, 0.0025, 0.005],
    'dropout_rate': [0.05, 0.075, 0.1],
    'seq_length': [10, 15, 20],
}

keys = list(param_grid.keys())
combos = list(product(*param_grid.values()))
print(f"Total combinations per sensor: {len(combos)}")

for sensor_id in [1, 2]:
    print(f"\n{'='*60}")
    print(f"  SENSOR {sensor_id} - Grid Search")
    print(f"{'='*60}\n")

    #### Split & Scale ####
    df_sub = df[df['sensor'] == sensor_id]
    X_train, X_test = train_test_split(df_sub, test_size=0.2, shuffle=False)
    df_train = X_train.reset_index()
    df_test = X_test.reset_index()

    scaler = MinMaxScaler()
    df_train[feature_cols] = scaler.fit_transform(df_train[feature_cols])
    df_test[feature_cols] = scaler.transform(df_test[feature_cols])

    results = []

    for i, combo in enumerate(combos):
        params = dict(zip(keys, combo))
        l1, l2 = params['layer_units']
        lr = params['learning_rate']
        dr = params['dropout_rate']
        sl = params['seq_length']

        # Build training sequences for this seq_length
        seq_arrays = []
        seq_labels = []
        for j in range(len(df_train) - sl - pred_horizon):
            seq_arrays.append(df_train[input_features].iloc[j:j+sl].values)
            seq_labels.append(df_train[output_features].iloc[j+sl+pred_horizon].values)
        seq_arrays = np.array(seq_arrays)
        seq_labels = np.array(seq_labels)

        # Build test sequences for this seq_length
        test_arrays = []
        test_labels = []
        for j in range(2, len(df_test) - pred_horizon):
            start_idx = max(0, j - sl)
            test_arrays.append(df_test[input_features].iloc[start_idx:j].values)
            test_labels.append(df_test[output_features].iloc[j + pred_horizon].values)
        test_arrays = pad_sequences(test_arrays, maxlen=sl, dtype='float32', padding='pre')
        test_labels = np.array(test_labels, dtype=np.float32)

        # Build model
        model = Sequential()
        model.add(Input(shape=(sl, n_inputs)))
        model.add(GRU(units=l1, return_sequences=True))
        model.add(Dropout(dr))
        model.add(GRU(units=l2, return_sequences=False))
        model.add(Dropout(dr))
        model.add(Dense(units=n_outputs))
        model.compile(optimizer=Adam(lr), loss='mse', metrics=['mse'])

        # Train
        history = model.fit(
            seq_arrays, seq_labels,
            epochs=100, batch_size=500, validation_split=0.05, verbose=0,
            callbacks=[EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)]
        )

        # Evaluate
        scores = model.evaluate(test_arrays, test_labels, verbose=0)
        test_mse = scores[1]

        best_val = min(history.history['val_loss'])
        epochs_run = len(history.history['loss'])

        results.append({
            'layer_units': (l1, l2), 'learning_rate': lr, 'dropout_rate': dr,
            'seq_length': sl, 'test_mse': test_mse, 'best_val_mse': best_val,
            'epochs': epochs_run
        })

        print(f"[{i+1}/{len(combos)}] units=({l1},{l2}) lr={lr} dr={dr} seq={sl} -> test_mse={test_mse:.6f} (epochs={epochs_run})")

    # Summary
    results_df = pd.DataFrame(results).sort_values('test_mse')
    print(f"\n=== Sensor {sensor_id} - Top 10 Configurations ===")
    print(results_df.head(10).to_string(index=False))
# Out:
# Total combinations per sensor: 54
#
# ============================================================
#   SENSOR 1 - Grid Search
# ============================================================
#
# [1/54] units=(64,32) lr=0.001 dr=0.05 seq=10 -> test_mse=0.006142 (epochs=52)
# [2/54] units=(64,32) lr=0.001 dr=0.05 seq=15 -> test_mse=0.006511 (epochs=20)
# [3/54] units=(64,32) lr=0.001 dr=0.05 seq=20 -> test_mse=0.006220 (epochs=23)
# [4/54] units=(64,32) lr=0.001 dr=0.075 seq=10 -> test_mse=0.006477 (epochs=35)
# [5/54] units=(64,32) lr=0.001 dr=0.075 seq=15 -> test_mse=0.006355 (epochs=46)
# [6/54] units=(64,32) lr=0.001 dr=0.075 seq=20 -> test_mse=0.006260 (epochs=60)
# [7/54] units=(64,32) lr=0.001 dr=0.1 seq=10 -> test_mse=0.006565 (epochs=38)
# [8/54] units=(64,32) lr=0.001 dr=0.1 seq=15 -> test_mse=0.006476 (epochs=36)
# [9/54] units=(64,32) lr=0.001 dr=0.1 seq=20 -> test_mse=0.006678 (epochs=35)
# [10/54] units=(64,32) lr=0.0025 dr=0.05 seq=10 -> test_mse=0.006232 (epochs=37)
# [11/54] units=(64,32) lr=0.0025 dr=0.05 seq=15 -> test_mse=0.006059 (epochs=58)
# [12/54] units=(64,32) lr=0.0025 dr=0.05 seq=20 -> test_mse=0.006479 (epochs=22)
# [13/54] units=(64,32) lr=0.0025 dr=0.075 seq=10 -> test_mse=0.006350 (epochs=30)
# [14/54] units=(64,32) lr=0.0025 dr=0.075 seq=15 -> test_mse=0.006347 (epochs=20)
# [15/54] units=(64,32) lr=0.0025 dr=0.075 seq=20 -> test_mse=0.006034 (epochs=35)
# [16/54] units=(64,32) lr=0.0025 dr=0.1 seq=10 -> test_mse=0.006245 (epochs=23)
# [17/54] units=(64,32) lr=0.0025 dr=0.1 seq=15 -> test_mse=0.006409 (epochs=52)
# [18/54] units=(64,32) lr=0.0025 dr=0.1 seq=20 -> test_mse=0.006080 (epochs=41)
# [19/54] units=(64,32) lr=0.005 dr=0.05 seq=10 -> test_mse=0.005864 (epochs=30)
# [20/54] units=(64,32) lr=0.005 dr=0.05 seq=15 -> test_mse=0.006063 (epochs=27)
# [21/54] units=(64,32) lr=0.005 dr=0.05 seq=20 -> test_mse=0.005958 (epochs=13)
# [22/54] units=(64,32) lr=0.005 dr=0.075 seq=10 -> test_mse=0.006503 (epochs=21)
# [23/54] units=(64,32) lr=0.005 dr=0.075 seq=15 -> test_mse=0.005960 (epochs=37)
# [24/54] units=(64,32) lr=0.005 dr=0.075 seq=20 -> test_mse=0.006167 (epochs=34)
# [25/54] units=(64,32) lr=0.005 dr=0.1 seq=10 -> test_mse=0.005882 (epochs=49)
# [26/54] units=(64,32) lr=0.005 dr=0.1 seq=15 -> test_mse=0.006058 (epochs=32)
# [27/54] units=(64,32) lr=0.005 dr=0.1 seq=20 -> test_mse=0.005720 (epochs=39)
# [28/54] units=(128,64) lr=0.001 dr=0.05 seq=10 -> test_mse=0.006265 (epochs=52)
# [29/54] units=(128,64) lr=0.001 dr=0.05 seq=15 -> test_mse=0.006484 (epochs=15)
# [30/54] units=(128,64) lr=0.001 dr=0.05 seq=20 -> test_mse=0.006264 (epochs=20)
# [31/54] units=(128,64) lr=0.001 dr=0.075 seq=10 -> test_mse=0.006194 (epochs=19)
# [32/54] units=(128,64) lr=0.001 dr=0.075 seq=15 -> test_mse=0.006169 (epochs=13)
# [33/54] units=(128,64) lr=0.001 dr=0.075 seq=20 -> test_mse=0.006146 (epochs=26)
# [34/54] units=(128,64) lr=0.001 dr=0.1 seq=10 -> test_mse=0.006433 (epochs=23)
# [35/54] units=(128,64) lr=0.001 dr=0.1 seq=15 -> test_mse=0.006323 (epochs=37)
# [36/54] units=(128,64) lr=0.001 dr=0.1 seq=20 -> test_mse=0.006465 (epochs=17)
# [37/54] units=(128,64) lr=0.0025 dr=0.05 seq=10 -> test_mse=0.005889 (epochs=32)
# [38/54] units=(128,64) lr=0.0025 dr=0.05 seq=15 -> test_mse=0.005951 (epochs=36)
# [39/54] units=(128,64) lr=0.0025 dr=0.05 seq=20 -> test_mse=0.006036 (epochs=16)
# [40/54] units=(128,64) lr=0.0025 dr=0.075 seq=10 -> test_mse=0.005865 (epochs=61)
# [41/54] units=(128,64) lr=0.0025 dr=0.075 seq=15 -> test_mse=0.005878 (epochs=24)
# [42/54] units=(128,64) lr=0.0025 dr=0.075 seq=20 -> test_mse=0.005891 (epochs=12)
# [43/54] units=(128,64) lr=0.0025 dr=0.1 seq=10 -> test_mse=0.005892 (epochs=35)
# [44/54] units=(128,64) lr=0.0025 dr=0.1 seq=15 -> test_mse=0.006187 (epochs=28)
# [45/54] units=(128,64) lr=0.0025 dr=0.1 seq=20 -> test_mse=0.005851 (epochs=28)
# [46/54] units=(128,64) lr=0.005 dr=0.05 seq=10 -> test_mse=0.005885 (epochs=21)
# [47/54] units=(128,64) lr=0.005 dr=0.05 seq=15 -> test_mse=0.006175 (epochs=18)
# [48/54] units=(128,64) lr=0.005 dr=0.05 seq=20 -> test_mse=0.006123 (epochs=15)
# [49/54] units=(128,64) lr=0.005 dr=0.075 seq=10 -> test_mse=0.005939 (epochs=25)
# [50/54] units=(128,64) lr=0.005 dr=0.075 seq=15 -> test_mse=0.006091 (epochs=20)
# [51/54] units=(128,64) lr=0.005 dr=0.075 seq=20 -> test_mse=0.005795 (epochs=24)
# [52/54] units=(128,64) lr=0.005 dr=0.1 seq=10 -> test_mse=0.006209 (epochs=14)
# [53/54] units=(128,64) lr=0.005 dr=0.1 seq=15 -> test_mse=0.006120 (epochs=23)
# [54/54] units=(128,64) lr=0.005 dr=0.1 seq=20 -> test_mse=0.005838 (epochs=19)
#
# === Sensor 1 - Top 10 Configurations ===
# layer_units  learning_rate  dropout_rate  seq_length  test_mse  best_val_mse  epochs
#    (64, 32)         0.0050         0.100          20  0.005720      0.004135      39
#   (128, 64)         0.0050         0.075          20  0.005795      0.004038      24
#   (128, 64)         0.0050         0.100          20  0.005838      0.003958      19
#   (128, 64)         0.0025         0.100          20  0.005851      0.004199      28
#    (64, 32)         0.0050         0.050          10  0.005864      0.004041      30
#   (128, 64)         0.0025         0.075          10  0.005865      0.003813      61
#   (128, 64)         0.0025         0.075          15  0.005878      0.004028      24
#    (64, 32)         0.0050         0.100          10  0.005882      0.003868      49
#   (128, 64)         0.0050         0.050          10  0.005885      0.003919      21
#   (128, 64)         0.0025         0.050          10  0.005889      0.003851      32
#
# ============================================================
#   SENSOR 2 - Grid Search
# ============================================================
#
# [1/54] units=(64,32) lr=0.001 dr=0.05 seq=10 -> test_mse=0.000646 (epochs=64)
# [2/54] units=(64,32) lr=0.001 dr=0.05 seq=15 -> test_mse=0.000670 (epochs=37)
# [3/54] units=(64,32) lr=0.001 dr=0.05 seq=20 -> test_mse=0.000720 (epochs=23)
# [4/54] units=(64,32) lr=0.001 dr=0.075 seq=10 -> test_mse=0.000684 (epochs=24)
# [5/54] units=(64,32) lr=0.001 dr=0.075 seq=15 -> test_mse=0.000717 (epochs=30)
# [6/54] units=(64,32) lr=0.001 dr=0.075 seq=20 -> test_mse=0.000673 (epochs=37)
# [7/54] units=(64,32) lr=0.001 dr=0.1 seq=10 -> test_mse=0.000714 (epochs=28)
# [8/54] units=(64,32) lr=0.001 dr=0.1 seq=15 -> test_mse=0.000679 (epochs=41)
# [9/54] units=(64,32) lr=0.001 dr=0.1 seq=20 -> test_mse=0.000739 (epochs=25)
# [10/54] units=(64,32) lr=0.0025 dr=0.05 seq=10 -> test_mse=0.000700 (epochs=21)
# [11/54] units=(64,32) lr=0.0025 dr=0.05 seq=15 -> test_mse=0.000629 (epochs=31)
# [12/54] units=(64,32) lr=0.0025 dr=0.05 seq=20 -> test_mse=0.000687 (epochs=27)
# [13/54] units=(64,32) lr=0.0025 dr=0.075 seq=10 -> test_mse=0.000661 (epochs=43)
# [14/54] units=(64,32) lr=0.0025 dr=0.075 seq=15 -> test_mse=0.000642 (epochs=50)
# [15/54] units=(64,32) lr=0.0025 dr=0.075 seq=20 -> test_mse=0.000661 (epochs=29)
# [16/54] units=(64,32) lr=0.0025 dr=0.1 seq=10 -> test_mse=0.000708 (epochs=23)
# [17/54] units=(64,32) lr=0.0025 dr=0.1 seq=15 -> test_mse=0.000663 (epochs=42)
# [18/54] units=(64,32) lr=0.0025 dr=0.1 seq=20 -> test_mse=0.000649 (epochs=39)
# [19/54] units=(64,32) lr=0.005 dr=0.05 seq=10 -> test_mse=0.000625 (epochs=66)
# [20/54] units=(64,32) lr=0.005 dr=0.05 seq=15 -> test_mse=0.000613 (epochs=35)
# [21/54] units=(64,32) lr=0.005 dr=0.05 seq=20 -> test_mse=0.000632 (epochs=36)
# [22/54] units=(64,32) lr=0.005 dr=0.075 seq=10 -> test_mse=0.000642 (epochs=31)
# [23/54] units=(64,32) lr=0.005 dr=0.075 seq=15 -> test_mse=0.000648 (epochs=18)
# [24/54] units=(64,32) lr=0.005 dr=0.075 seq=20 -> test_mse=0.000710 (epochs=19)
# [25/54] units=(64,32) lr=0.005 dr=0.1 seq=10 -> test_mse=0.000631 (epochs=51)
# [26/54] units=(64,32) lr=0.005 dr=0.1 seq=15 -> test_mse=0.000649 (epochs=27)
# [27/54] units=(64,32) lr=0.005 dr=0.1 seq=20 -> test_mse=0.000659 (epochs=23)
# [28/54] units=(128,64) lr=0.001 dr=0.05 seq=10 -> test_mse=0.000638 (epochs=35)
# [29/54] units=(128,64) lr=0.001 dr=0.05 seq=15 -> test_mse=0.000657 (epochs=36)
# [30/54] units=(128,64) lr=0.001 dr=0.05 seq=20 -> test_mse=0.000615 (epochs=50)
# [31/54] units=(128,64) lr=0.001 dr=0.075 seq=10 -> test_mse=0.000722 (epochs=20)
# [32/54] units=(128,64) lr=0.001 dr=0.075 seq=15 -> test_mse=0.000665 (epochs=28)
# [33/54] units=(128,64) lr=0.001 dr=0.075 seq=20 -> test_mse=0.000722 (epochs=16)
# [34/54] units=(128,64) lr=0.001 dr=0.1 seq=10 -> test_mse=0.000678 (epochs=38)
# [35/54] units=(128,64) lr=0.001 dr=0.1 seq=15 -> test_mse=0.000652 (epochs=46)
# [36/54] units=(128,64) lr=0.001 dr=0.1 seq=20 -> test_mse=0.000693 (epochs=24)
# [37/54] units=(128,64) lr=0.0025 dr=0.05 seq=10 -> test_mse=0.000644 (epochs=17)
# [38/54] units=(128,64) lr=0.0025 dr=0.05 seq=15 -> test_mse=0.000612 (epochs=46)
# [39/54] units=(128,64) lr=0.0025 dr=0.05 seq=20 -> test_mse=0.000655 (epochs=37)
# [40/54] units=(128,64) lr=0.0025 dr=0.075 seq=10 -> test_mse=0.000647 (epochs=26)
# [41/54] units=(128,64) lr=0.0025 dr=0.075 seq=15 -> test_mse=0.000627 (epochs=36)
# [42/54] units=(128,64) lr=0.0025 dr=0.075 seq=20 -> test_mse=0.000649 (epochs=18)
# [43/54] units=(128,64) lr=0.0025 dr=0.1 seq=10 -> test_mse=0.000646 (epochs=30)
# [44/54] units=(128,64) lr=0.0025 dr=0.1 seq=15 -> test_mse=0.000637 (epochs=26)
# [45/54] units=(128,64) lr=0.0025 dr=0.1 seq=20 -> test_mse=0.000632 (epochs=23)
# [46/54] units=(128,64) lr=0.005 dr=0.05 seq=10 -> test_mse=0.000610 (epochs=51)
# [47/54] units=(128,64) lr=0.005 dr=0.05 seq=15 -> test_mse=0.000613 (epochs=36)
# [48/54] units=(128,64) lr=0.005 dr=0.05 seq=20 -> test_mse=0.000648 (epochs=19)
# [49/54] units=(128,64) lr=0.005 dr=0.075 seq=10 -> test_mse=0.000627 (epochs=30)
# [50/54] units=(128,64) lr=0.005 dr=0.075 seq=15 -> test_mse=0.000611 (epochs=51)
# [51/54] units=(128,64) lr=0.005 dr=0.075 seq=20 -> test_mse=0.000606 (epochs=31)
# [52/54] units=(128,64) lr=0.005 dr=0.1 seq=10 -> test_mse=0.000635 (epochs=29)
# [53/54] units=(128,64) lr=0.005 dr=0.1 seq=15 -> test_mse=0.000664 (epochs=18)
# [54/54] units=(128,64) lr=0.005 dr=0.1 seq=20 -> test_mse=0.000630 (epochs=35)
#
# === Sensor 2 - Top 10 Configurations ===
# layer_units  learning_rate  dropout_rate  seq_length  test_mse  best_val_mse  epochs
#   (128, 64)         0.0050         0.075          20  0.000606      0.002597      31
#   (128, 64)         0.0050         0.050          10  0.000610      0.002526      51
#   (128, 64)         0.0050         0.075          15  0.000611      0.002562      51
#   (128, 64)         0.0025         0.050          15  0.000612      0.002584      46
#    (64, 32)         0.0050         0.050          15  0.000613      0.002563      35
#   (128, 64)         0.0050         0.050          15  0.000613      0.002602      36
#   (128, 64)         0.0010         0.050          20  0.000615      0.002614      50
#    (64, 32)         0.0050         0.050          10  0.000625      0.002575      66
#   (128, 64)         0.0025         0.075          15  0.000627      0.002625      36
#   (128, 64)         0.0050         0.075          10  0.000627      0.002590      30
